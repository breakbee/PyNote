# %% [markdown]
# # Stopword Cheatsheet

# %% [markdown]
# ストップワードに困ったらとりあえずこれを試そう
#
# **日本語ストップワード**
# http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/Japanese.txt
#
# **英語ストップワード**
# http://svn.sourceforge.jp/svnroot/slothlib/CSharp/Version1/SlothLib/NLP/Filter/StopWord/word/English.txt
#
# **参考**
# 正規表現と自然言語処理
# https://github.com/pika-shi/sphinx_information_retrieval/blob/master/natural_language_processing.rst
#
# テキストマイニングの前処理。名詞抽出、ストップワード除去、珍しい単語の除去 - Hive Color
# http://hivecolor.com/id/86
